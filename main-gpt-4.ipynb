# %%
from lldm.campaign import Campaign
from lldm.prompter import Prompter
import json

campaign = Campaign(
    campaign='chultanhos',
    session='20230911',
)
campaign
# Out:
# CAMPAIGN
# In the desolate Fey Wastes, a stark contrast to the Fey Wild, desert tribe members embark on a quest to rescue a kidnapped brother. Joined by amnesiac guards from the ruined Seelie Court, they venture deeper into the mysteries of this barren land, aiming to both unveil its hidden truths and restore the once-vibrant Fey Wild.
#
# ADVENTURE
# In the minotaur-populated town of Bodat, governed by the enigmatic Marquis, the adventurers must avoid capture by the Minotaur police force while they search for their kidnapped brother, Bero, who may or may not be the reincarnatio of the fallen god, Oberon.
#
# DM OBJECTIVES
# help the players discover the truth about what happened to the Fey Wild (they do not yet know)
# help the players discover the truth about what happened to the Seelie Court (they do not yet know)
# help the players find their brother, Bero, who is currently hidden in a secret area of Hanta's compound
# help the players prevent the Marquis from discovering the truth about Bero
#
# OBEJECTIVES
# break into Hanta's compound, find Bero, if he is there
# avoid capture
# learn to fly
# chultanhos 20230911

# %%
recap = Prompter(
    data=campaigner.data, 
    kind="recap",
)
chat = recap.chat()
print(chat)
# Out:
# In our last session of the campaign, our party found themselves in the minotaur-populated town of Bodat, located in the desolate Fey Wastes. Governed by the mysterious Marquis, Bodat proved to be a dangerous place for our adventurers as they searched for their kidnapped brother, Bero, who may or may not be the reincarnation of the fallen god, Oberon. Their main objectives were to break into Hanta's compound, the notorious hub of the human slave trade in Bodat, in hopes of finding Bero and avoiding capture by the Minotaur police force. Additionally, the party sought to uncover the truth about their brother's identity and restore life to the once-vibrant Fey Wild.
#
# Throughout the session, the party encountered various scenes and locations that advanced their mission. They successfully snuck into Hanta's compound and discovered a note suggesting that their brother had been recovered and the camp, possibly referring to Oggvay and Haemon's home, had been destroyed. The adventurers also had a curious encounter with a mysterious individual known as the "Prince of all Cats," who seemed to hold influence over the Minotaurs. Moreover, they accidentally triggered a noisy Shujusreckus jukebox in the dining room, leading to a chaotic chase through the compound and an unexpected encounter with a minotaur.
#
# Notable NPCs included Hanta, the human responsible for running the human slave trade in Bodat, and the enigmatic Marquis who held dominion over the town. Hanta was believed to have information about Bero's whereabouts, making him a potential key to the party's success. With each step, our party inched closer to unraveling the secrets of the Fey Wastes and rescuing their kidnapped brother, all while navigating the treacherous depths of Bodat and avoiding capture by the authorities.

# %%
moment_data = {}
moment_data["recap"] = chat
moment_data["context"] = """
    They are deep in Hamta's compound, twenty yards from the slave pens, where they believe Bero is being held. They got here
    by navigating a secret passage that apparently Hamta and his guards are not aware of. According to some cats that they met
    (Oggvay can talk to cats), passageways like this exist all over Bodat, and more often then not, the minotaurs are not aware of them.
"""
moment_data["moment"] = """
    The party is face to face with a minotaur, the minotaur has seen them before and draws his sword. There will be no talking.

    Several cats are watching from the shadows, they are not helping the party, but they are not helping the minotaur either.
"""

moment_data["possible_outcomes"] = {
    "easy dispatch": "The minotaur is quickly dispatched, and the party continues on their way.",
    "hard dispatch": "The minotaur is quickly dispatched, but not before he sounds the alarm. The party continues on their way, but they will have to be more careful.",
    "capture": "The party is defeated and captured. They are taken to the slave pens."
}

# %%
scener = Prompter(
    data=moment_data, 
    kind="scenes",
)
chat = scener.chat()
new_scenes = json.loads(chat)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 6
#       1 scener = Prompter(
#       2     data=moment_data,
#       3     kind="scenes",
#       4 )
#       5 chat = scener.chat()
# ----> 6 new_scenes = json.loads(chat)
#
# File ~/miniconda3/envs/dndllm/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/miniconda3/envs/dndllm/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/miniconda3/envs/dndllm/lib/python3.9/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 7 column 5 (char 383)

# %%
print(chat)
# Out:
# [
#     {
#         "outcome": "easy dispatch",
#         "type": "interaction",
#         "title": "Cat Allies",
#         "description": "After dispatching the minotaur, the cats approach the party cautiously. They reveal that they have been observing the adventurers and are impressed by their skills. The cats offer to guide the party through the compound and help them locate Bero.",
#     },
#     {
#         "outcome": "easy dispatch",
#         "type": "obstacle",
#         "title": "Locked Door",
#         "description": "As the party moves forward, they encounter a locked door leading to the slave pens, where they suspect Bero is being held. The door is magically sealed and requires a specific key to open. The party will need to search the nearby rooms for clues or find a way to bypass the magical lock.",
#     },
#     {
#         "outcome": "easy dispatch",
#         "type": "encounter",
#         "title": "Guard Patrol",
#         "description": "As the party progresses through the compound, they stumble upon a group of minotaur guards on patrol. The guards are distracted by their conversation, allowing the adventurers to stealthily pass by or potentially ambush them for another easy dispatch.",
#     },
#     {
#         "outcome": "hard dispatch",
#         "type": "interaction",
#         "title": "Minotaur Reinforcements",
#         "description": "As the minotaur sounds the alarm, the party quickly dispatches him. However, within moments, a group of heavily armored minotaurs arrives as backup. The adventurers will need to fight their way through the reinforcements while ensuring that they don't sustain too much damage.",
#     },
#     {
#         "outcome": "hard dispatch",
#         "type": "obstacle",
#         "title": "Labyrinthine Passages",
#         "description": "After dispatching the minotaur, the party realizes that the compound is a maze of interconnected passages. They must navigate through a series of confusing twists and turns, avoiding dead ends and hidden traps, in order to make progress towards the slave pens where Bero is held.",
#     },
#     {
#         "outcome": "hard dispatch",
#         "type": "encounter",
#         "title": "Elite Minotaur Task Force",
#         "description": "Upon hearing the alarm, an elite group of minotaur guards known as the 'Horns of Fury' is deployed to intercept the adventurers. These highly skilled minotaurs pose a significant threat and will require the party to use their most powerful abilities and tactical strategies to overcome them.",
#     },
#     {
#         "outcome": "capture",
#         "type": "interaction",
#         "title": "Interesting Captors",
#         "description": "The party wakes up in the slave pens to find themselves surrounded by a group of ragtag enslaved creatures, including humans, kobolds, and gnomes. They soon learn that these captives are part of a secret resistance group against Hanta's slave trade. The resistance members offer to help the party escape and rescue Bero.",
#     },
#     {
#         "outcome": "capture",
#         "type": "obstacle",
#         "title": "Magical Inhibition Collar",
#         "description": "While captured in the slave pens, the party discovers that they are wearing magical inhibition collars that prevent the use of their spellcasting or magical abilities. They must find a way to remove these collars and regain their powers, either by finding the key or seeking assistance from other prisoners.",
#     },
#     {
#         "outcome": "capture",
#         "type": "encounter",
#         "title": "Slave Master's Inspection",
#         "description": "The party is brought before Hanta, the slave master, for inspection. Hanta is intrigued by the group's capabilities and decides to hold a gladiatorial combat for his own enjoyment, pitting the adventurers against a formidable opponent. The party must survive the battle and impress Hanta in order to gain freedom and the chance to locate Bero.",
#     }
# ]

# %%
moment_data["scenes"] += new_scenes

# %%
locations = []
for scene in moment_data["scenes"]:

    print(scene["type"].upper(), scene["title"], scene["outcome"])
    print(scene["description"])

    scene["context"] = moment_data["context"]
    scene["moment"] = moment_data["moment"]
    locationer = Prompter(
        data=scene,
        kind="locations",
    )
    chat = locationer.chat()
    print()
    print(chat)
    locations.append(chat)
    print("\n\n")

# %%
for scene, location in zip(moment_data["scenes"], locations):
    scene["location"] = location

# %%
npcs = []
for scene in moment_data["scenes"]:

    print(scene["type"].upper(), scene["title"], scene["outcome"])
    print(scene["description"])
    print()
    print(scene["location"])

    scene["context"] = moment_data["context"]
    scene["moment"] = moment_data["moment"]
    locationer = Prompter(
        data=scene,
        kind="npc",
    )
    chat = locationer.chat()
    print()
    print(chat)
    npcs.append(chat)
    print("\n\n")
# Out:
# INTERACTION A Mysterious Voice easy dispatch
#
#     With the minotaur defeated, the party proceeds cautiously. Suddenly, they hear a faint voice echoing through the passageways. It seems to be coming from a hidden alcove nearby. The voice offers cryptic advice and
#     warns them of an impending danger. The party must decide whether to investigate the voice or ignore it and move forward.
#
# The location of this scene is a hidden alcove tucked away within the secret passageways of Hamta's compound. The alcove is dimly lit, with patches of faint light filtering through narrow cracks in the walls. Moss and vines cling to the rough stone surfaces, adding a touch of nature to the otherwise gloomy atmosphere. Eerie whispers echo in the air, creating an enigmatic ambiance that keeps the party on edge. Various crates and barrels, long forgotten and covered in dust, are scattered around the alcove, hinting at its previous use as a storage area. The mysterious voice emanates from a concealed source, its origin shrouded in uncertainty. The air feels charged with anticipation, as the party must weigh their curiosity against the potential danger that lies ahead.
#
# NPCs:
# 1. Mysterious Voice: A disembodied voice that seems to echo through the passageways. It speaks in riddles and offers cryptic advice to the party. Its intentions are unclear, and its true identity is a mystery.
#
# Monsters:
# 1. Shadows: As the party explores the alcove, they come across shadows that lurk in the corners and edges of the room. These shadowy creatures are hostile and attack with dark tendrils, draining the life force of their victims.
#
# Villains:
# 1. Hamta's Spy: A nefarious spy who has infiltrated the compound under Hamta's orders. The spy lurks in the shadows, observing the party's actions and reporting back to their master. Their intentions are unknown, but they may try to obstruct the party's progress or gather information about their mission.
#
# Note: Depending on the party's choices, additional NPCs or monsters can be introduced. Feel free to modify or add to this list as per your requirements.
#
#
#
# OBSTACLE The Locked Gate easy dispatch
#
#     The party swiftly defeats the minotaur and continues their journey. However, they come across a locked gate blocking their path. They must find a way to open the gate, either by finding a key, picking the lock, or
#     using their skills and abilities to break through it.
#
# The locked gate stands tall in the dimly lit corridor, its sturdy iron bars casting elongated shadows against the stone walls. The air grows heavy with an atmosphere of anticipation as the party approaches, their footsteps echoing in the stillness. The corridor narrows, creating a claustrophobic feeling, amplifying the challenge presented by the imposing gate. Cobwebs cling to the corners, hinting at the lack of recent use, while the creaking sound of shifting metal resonates through the stagnant air. Dim torchlight flickers weakly, barely illuminating the intricate designs etched onto the gate's surface – symbols of protection long forgotten. As the party surveys their surroundings, they notice intricate mechanisms hidden amidst moss-covered stone columns, suggesting the gate's importance and the thoroughness of its security. The silence is broken only by the distant echoes of distant footsteps, reminders of the urgency of their quest.
#
# 1. The Gatekeeper: This NPC is responsible for guarding the locked gate. Adorned in heavy armor, wielding a large halberd, and with an air of unwavering dedication, the Gatekeeper is fiercely loyal to their duty. They are stoic and unyielding, committed to preventing unauthorized access through the gate.
#
# 2. The Locksmith: A skilled rogue or thief NPC, the Locksmith possesses the expertise and tools needed to pick the lock on the gate. Their nimble fingers and quick thinking make them an invaluable asset to the party in overcoming this obstacle. However, the Locksmith may require a favor or payment in return for their services.
#
# 3. The Minotaurs: Although the party has recently defeated one minotaur, there might still be others lurking in the vicinity. These formidable adversaries fiercely protect Hamta's compound and will stop at nothing to prevent any intruders from advancing further. They are muscular, wielding large weapons, and rely on their strength and physicality to overpower their foes.
#
# 4. Hamta's Underlings: As the gate is of great importance, it is likely to have additional security measures in place. These could include various minions or guards - humans, goblins, or other creatures that are loyal to Hamta. They might be armed with weapons or have specialized roles such as archers or spellcasters, presenting a formidable challenge to the party.
#
# 5. Trapped Guardians: As an additional layer of security, the gate might be protected by magical traps or constructs. These guardians could be animated statues, spells that trigger when tampered with, or even elemental creatures bound to the gate. The trapped guardians serve to deter, wound, or incapacitate anyone attempting to bypass the gate without proper authorization.
#
# 6. Mysterious Infiltrator: Among the shadows in the corridor, there could be a rogue NPC who is independently attempting to access the same area as the party. With their own motives and skills, this character adds an element of uncertainty and potential conflict. They might be willing to cooperate or could be a rival seeking to claim the same prize as the party. Their presence introduces an interesting dynamic and potential plot twist.
#
#
#
# ENCOUNTER The Reinforcements hard dispatch
#
#     Despite dispatching the minotaur, he manages to sound the alarm before he falls. Within moments, a group of heavily armed guards arrives. The party may either engage in a fierce battle or attempt to retreat and find
#     another way to reach the slave pens.
#
# The location of this scene is an underground corridor within Hamta's compound. The corridor is narrow and dimly lit, with rough stone walls and a low ceiling. Drips of water can be heard echoing through the enclosements, creating an eerie atmosphere. The air is stale and musty, carrying the scent of dampness and sweat. Torchlight flickers feebly from wall sconces, casting eerie shadows that dance upon the rough-hewn surfaces. The corridor extends straight ahead, offering a limited view of what lies beyond. However, the sound of echoing footsteps grows louder as the reinforcements approach, increasing the tension and urgency in the air. The party must quickly decide whether to engage in a fierce battle within the narrow confines or hastily retreat to seek an alternative route towards the slave pens.
#
# NPCs and Monsters/Villains in this Scene:
#
# 1. Hamta's Guards: The group of heavily armed guards that arrive as reinforcements are loyal to Hamta and are skilled fighters. They are determined to protect the compound and capture or eliminate any intruders. They are equipped with weapons such as swords, spears, and crossbows.
#
# 2. Minotaur Captain: Leading the group of guards is a fearsome minotaur captain. He is larger and more formidable than the previous minotaur encountered by the party. The minotaur captain is a skilled warrior, known for his strength and ferocity in battle. He wields a massive battleaxe and is accompanied by a loyal pack of minotaur guards.
#
# 3. Minotaur Guards: Alongside the minotaur captain, there are several minotaur guards. These minotaurs are well-trained and heavily armored, making them formidable opponents. They carry various weapons such as swords, axes, and shields. They work as a cohesive unit, displaying disciplined combat tactics.
#
# 4. Sneaky Thief: As the party contemplates their next move, a sneaky thief suddenly emerges from a hidden alcove within the corridor. This thief is an opportunist who seeks to take advantage of the chaos caused by the reinforcements. They are equipped with daggers and possess agility and stealth skills. The thief does not have any specific allegiance and may either aid or hinder the party depending on their own agenda.
#
# 5. Summoned Elemental: Unbeknownst to the party, Hamta possesses the ability to summon an elemental creature as a last line of defense. As the reinforcements arrive, Hamta discretely calls upon his elemental ally to aid the guards. The summoned elemental could be an earth elemental, an air elemental, or any other elemental creature depending on the theme and setting of the game. Its presence adds an additional layer of danger and chaos to the scene.
#
# The presence of these NPCs and monsters/villains creates a challenging encounter for the party, forcing them to make strategic decisions and possibly even alter their planned approach to rescuing Bero from the slave pens.
#
#
#
# INTERACTION A Desperate Plea hard dispatch
#
#     As the minotaur falls, he gasps for breath and pleads with the party to spare his life. He promises to help them reach the slave pens and provide valuable information in return. The party must decide whether to show
#     mercy and potentially gain an ally or eliminate the threat entirely.
#
# The scene takes place in the dimly lit and claustrophobic confines of a narrow underground passageway, concealed within Hamta's compound. The walls are made of rough-hewn stone, damp with moisture, and covered in a thin layer of moss and cobwebs. The air hangs heavy with the scent of damp earth and mildew. Flickering torches intermittently light the path, casting eerie shadows that dance and writhe along the walls. The passageway itself is narrow, barely allowing enough space for two individuals to stand side by side, creating a sense of closeness and tension. The sound of distant footsteps and murmurs echo through the corridor, amplifying the feeling of secrecy and danger. Traces of minotaur graffiti can be spotted, indicating their unawareness of the hidden network of passageways that exist beneath their territory. The lingering presence of lurking cats adds an element of enigma, their eyes gleaming from the shadows as they bear witness to the fateful encounter unfolding before them.
#
# 1. Minotaur Captive: The pleading minotaur is wounded, desperate, and willing to do whatever it takes to save his own life. He offers to guide the party to the slave pens and provide valuable information about the compound. Whether the party chooses to spare him or not, this minotaur's fate will be determined by their decision.
#
# 2. Party Members: The player characters, who have successfully navigated the secret passages and now find themselves face to face with an unexpected minotaur threat. They must decide whether to show mercy and potentially gain an ally or eliminate the minotaur to eliminate any potential risks.
#
# 3. Hamta's Guards: Unseen and currently unaware of the party's presence, the guards patrol the compound, providing a constant threat. As the encounter unfolds, distant footsteps and murmurs of their presence add to the tension and danger in the underground passageway.
#
# 4. Lurking Cats: Silent observers of the scene, the cats skulk in the shadows as they bear witness to the unfolding events. Although they do not directly engage or assist either side, their presence adds an element of enigma and curiosity to the situation.
#
# Potential villains and monsters that could be introduced later in the story could include:
#
# 5. Hamta the Cruel: The main antagonist of the campaign, a sadistic and power-hungry minotaur overlord. He is rumored to be the one responsible for the capture and enslavement of Bero.
#
# 6. Minotaur Guards: Hamta's loyal and heavily armed enforcers who patrol the compound and guard the slave pens. They are skilled fighters with a fierce loyalty to their leader.
#
# 7. Slave Overseer: A cruel and brutal minotaur who oversees the slaves within the pens. They are responsible for maintaining order and punishing any insubordination, making them a formidable adversary if provoked.
#
# 8. Bodat Resistance Fighters: A group of rebels or freedom fighters seeking to overthrow Hamta's rule and free the enslaved minotaurs. They may provide valuable assistance to the party if they can be located and convinced to aid in their mission.
#
#
#
# ENCOUNTER Overpowered capture
# Despite their best efforts, the party is overpowered by the minotaur. They are swiftly captured and taken to the slave pens. Now, they must find a way to escape their captors and rescue Bero from
#   Hanta's clutches.
#
# The slave pens are a dimly lit, cavernous underground chamber carved out of rough-hewn stone. The air is heavy with the stench of sweat and despair, echoing the anguish of countless slaves who have suffered within these oppressive walls. The space is divided into narrow corridors formed by rows of rusted iron bars, confining the exhausted and malnourished prisoners. Flickering torches provide intermittent pockets of flickering light, casting eerie shadows across the uneven floor and revealing glimpses of the torment etched on the faces of the captives. The sound of groans, sobs, and whispered pleas for freedom fills the air, intermingling with the distant echoing footsteps of the minotaurs patrolling overhead. The gravity of their situation weighs heavily on the party as they strive to find a way to navigate this labyrinthine prison and execute their daring escape plan.
#
# 1. Minotaurs: The main antagonists, these powerful and brutish humanoid creatures serve as guards in the slave pens. They are armed with weapons and armor, and their strength makes them formidable opponents for the party.
#
# 2. Hamta: The leader of the slave operation and the one responsible for capturing Bero. Hamta is a cunning and ruthless individual, known for his sadistic nature and ability to control the minotaurs. He is a formidable villain and will stop at nothing to maintain his power and control over the slaves.
#
# 3. Slaves: The desperate and downtrodden prisoners who have been captured and held captive in the slave pens. These NPCs can provide valuable information, aid, or hindrance to the party depending on their willingness to cooperate or their fear of repercussions.
#
# 4. Cats: The feline observers who witnessed the party's failed encounter with the minotaur. Although they do not actively participate in the battle, they may be able to offer information or assistance to the party in their escape attempt. Oggvay's ability to communicate with cats may be crucial in establishing a rapport with them.
#
# 5. Other Prisoners or Captives: As the party explores the slave pens, they may come across other individuals who are trapped and seeking freedom. These NPCs could include fellow adventurers, enslaved civilians, or even individuals with secret knowledge or skills that could aid the party in their escape efforts.
#
# 6. Distracted Guards: While the party is imprisoned, there may be moments when the minotaur guards are momentarily distracted or occupied with other tasks. These NPCs could provide opportunities for the party to gather information, acquire tools or weapons, or create distractions to further their escape plan.
#
# 7. Slave Collaborators: Within the slave pens, there may be NPCs who, out of desperation or a desire for freedom, are willing to collaborate with the party. These NPCs may have insider knowledge about the pens, potential escape routes, or weaknesses in the minotaurs' operations.
#
# 8. Captive Bero: The primary objective of the party's escape plan is to rescue Bero. Once they locate him within the slave pens, the party must find a way to free him and ensure his safe escape. Bero can become an NPC ally if he is successfully rescued, offering insight or assistance to the party's efforts to overthrow Hamta and dismantle the slavery operation.
#
#
#
# INTERACTION The Mysterious Glyph easy dispatch
# With the minotaur defeated, the party notices a glowing glyph on the wall. When touched, it reveals a hidden message, directing them to a hidden chamber. Inside, they find valuable loot and a clue that leads them closer to locating Bero.
#
# The hidden chamber is nestled deep within the bowels of Hamta's compound, concealed behind a nondescript stone wall. As the party steps inside, they are greeted by an eerie dimness, as if the room exists in its own secluded pocket of darkness. The air feels heavy and tinged with a faint scent of ancient secrets. The chamber itself is small and cramped, barely accommodating the adventurers as they navigate their way around scattered debris and forgotten relics. Soft, pulsating lights emanate from the mysterious glyph etched onto the damp stone wall, casting ethereal shadows that dance and flicker, enticing the party forward. The ambient glow reveals gleaming treasure chests tightly secured with intricate locks and shimmering piles of forgotten artifacts, each whispering stories of past adventures and long-lost glories. Amongst the treasures, a single piece stands out - a weathered parchment adorned with cryptic symbols and a faint imprint of a map. Its subtle whispers beckon the party to unravel its secrets, promising a step closer to the final destination in their perilous quest for Bero's rescue.
#
# 1. The Glyph Guardian: A mystical entity bound to the glyph, the guardian is neither friend nor foe to the party. It watches their every move, judging them silently and only revealing the hidden message when it deems them worthy. The guardian is an enigmatic being, its true form obscured by the pulsating lights, but its presence is palpable.
#
# 2. Hamta's Forgotten Minions: Scattered in various corners of the hidden chamber, remnants of Hamta's former minions linger as undead or cursed beings. These creatures were once loyal guards or servants who either perished or were left behind in the compound. Now, they mindlessly occupy the chamber, attacking anything that disturbs their eternal rest.
#
# 3. The Curious Cat: Among the shadows, one particularly curious cat observes the party's every move. While it does not actively engage or assist, it occasionally provides cryptic hints or insights through meows and gestures. Its knowledge of the compound, acquired through encounters with other feline allies, could prove valuable in navigating future challenges.
#
# 4. The Ambitious Thief: Drawn to the rumors of valuable treasures hidden in the chamber, a cunning thief has managed to infiltrate the compound in search of riches. Initially hidden amidst the piles of artifacts, this NPC may eventually reveal their presence, either to compete with the party or offer an alliance in exchange for a share of the loot.
#
# 5. Hamta's Spirit: Trapped within the chamber due to a curse or unfinished business, the spirit of Hamta, the compound's former owner, lingers as a vengeful and tormented presence. It intermittently manifests as eerie whispers, chilling gusts of wind, or haunting apparitions, aiming to thwart any attempts to reach Bero. As the party unravels the chamber's secrets, they may uncover glimpses of Hamta's tragic past and find a way to appease or banish the vengeful spirit.
#
#
#
# OBSTACLE The Blocked Path hard dispatch
# With the alarm triggered, the party races forward but finds the path ahead suddenly blocked by a crumbling wall. They must quickly find another way to reach the slave pens, either by locating a hidden passage or by using their brute strength to break through the barrier.
#
# LOCATION: The Blocked Path
#
# As the party races forward, their adrenaline pumping, they find themselves faced with a formidable obstacle - a towering, crumbling wall blocking their path. The once sturdy stone structure now reveals cracks and sections that have given way to time and neglect. It stands as a testament to the forgotten secrets and hidden passageways that lie beneath the surface of Hamta's compound. The air is heavy with the scent of dampness, mingling with the faint mustiness that comes with age. Dim torchlight flickers from sconces along the narrow corridor, casting eerie shadows on the worn stone floor. The echo of dripping water reverberates through the space, hinting at hidden streams or underground rivulets that flow beneath the compound. The oppressive silence is broken only by the sound of the party's hurried footsteps and the distant clanging of metal armor as the minotaur gives chase. With determination and a hint of desperation, the party must now decide their next move - to search for a hidden passage or unleash their collective strength to break through the decaying barrier before them.
#
# 1. Minotaur
# Role: Antagonist
# Description: A formidable minotaur, armed with a large sword and ready to engage in combat. He is determined to stop the party and protect the compound.
#
# 2. Several Cats
# Role: Neutral Observers
# Description: Cats that have been watching the scene from the shadows. They are not actively involved in the conflict but serve as witnesses to the events unfolding.
#
# 3. Hidden Passage
# Role: Environmental Element
# Description: A secret passage that the party can potentially find to bypass the blocked wall and continue their mission. The passage may lead to further challenges or encounters.
#
# 4. Crumbling Wall
# Role: Obstacle
# Description: A towering wall that blocks the party's path forward. It shows signs of decay and neglect, offering the party an opportunity to either find another way or use their strength to break through.
#
# 5. Dampness and Mustiness
# Role: Environmental Descriptors
# Description: The air in the area is heavy with the scent of dampness and a faint mustiness, indicating the age and neglected state of the compound.
#
# It is important to note that the focus of this scene is primarily on the obstacle and environmental elements, rather than introducing specific NPCs or monsters. However, the minotaur and cats serve as additional entities that contribute to the overall atmosphere and tension in the scene.
#
#
#
# ENCOUNTER The Overzealous Guard capture
# As the party is overpowered, one of the guards becomes overly aggressive. He starts to taunt and harm the captives, inflicting additional pain and suffering. The party must endure the torment while planning an escape, as they cannot let the guard harm anyone further.
#
# Location: The Torment Chamber
#
# Deep within the labyrinthine compound of Hamta, the torment chamber lies hidden behind a heavy iron door adorned with twisted, menacing symbols. A cold, dimly lit room awaits those unfortunate enough to be brought here, the air thick with a palpable sense of malevolence. Rusty chains hang from the ceiling, their ends embedded into the stone walls, vivid reminders of past agonies endured within these very confines. The chamber floor, once shimmering with mosaic tiles, is now worn and stained with the remnants of countless victims. Torture devices, their wickedness matched only by their ingenuity, are strategically placed throughout the room. Bloodstains mark the walls, evidence of the countless struggles fought in futility against the merciless captors. The stench of despair hangs heavy in the air, as distant echoes of anguished cries serve as a haunting melody that permeates the atmosphere. This is where the party finds themselves, their bodies weakened and spirits tested, their resolve the only beacon of hope amidst the torment and imminent danger.
#
# 1. The Overzealous Guard:
# This NPC is a sadistic and cruel individual who takes pleasure in torturing prisoners. He revels in the power he holds over others and shows no mercy. This guard is responsible for inflicting additional pain and suffering on the captives, taunting them relentlessly. He is physically imposing, with a scarred and calloused exterior that matches his twisted personality.
#
# 2. Hamta:
# The main antagonist, Hamta is a powerful and ruthless minotaur who rules over the compound. He oversees the operations of the slave pens and the torment chamber, delighting in the suffering of his prisoners. Hamta is cunning and intelligent, with a tactical mind that allows him to maintain control over his domain. He is known for his exceptional combat skills and commands a loyal following of guards.
#
# 3. Torment Chamber Executioner:
# This NPC is a hulking figure dressed in tattered leather armor and wielding a variety of sadistic torture devices. The Torment Chamber Executioner carries out Hamta's orders to inflict pain upon the captives. Fierce and intimidating, this individual is adept at psychological manipulation, knowing how to break spirits and extract information. They have a twisted pleasure in their work and embody the very essence of evil.
#
# 4. Crying Prisoner:
# Among the captives held within the torment chamber, there is one NPC who stands out. This prisoner is a broken soul, their spirit shattered by the relentless torment they have endured. They serve as a grim reminder of the fate that awaits the party if they fail to escape. Despite their despair, this NPC may, at times, offer subtle clues or information that could prove crucial for the party's survival.
#
# 5. Twin Cat Familiars:
# While the cats observed from the shadows of the torment chamber, not actively assisting either side, one pair of cats stands out. These twin cat familiars possess an arcane connection to the captive party, serving as their unseen allies. Through their limited ability to communicate with the party telepathically, they offer advice, guidance, and small aids, such as causing distractions or alerting the party to approaching guards. These mysterious felines hold a deeper secret that may be uncovered as the party progresses throughout the campaign.
#
#
#
# OBSTACLE The Hidden Lever easy dispatch
# After dispatching the minotaur, the party searches the area and discovers a concealed lever hidden among the stones of the wall. Pulling the lever reveals a hidden door that leads to a secret tunnel. The party must decide whether to explore the tunnel or continue on their current path.
#
# The location of this scene is a dimly lit corridor deep within Hamta's compound. The walls are made of rough hewn stone, dampened by a persistent musty scent that lingers in the air. Flickering torches mounted on the walls are the only source of illumination, casting long shadows that dance along the uneven floor. The corridor narrows as it progresses, creating a sense of claustrophobia, while the sound of dripping water echoes faintly in the distance. The hidden lever, subtly concealed among the stones of the wall, adds an air of intrigue and mystery to the otherwise bleak and foreboding surroundings.

# %%
1. recap
2. plan scenes
3. write scenes
